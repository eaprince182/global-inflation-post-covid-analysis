# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27563/3887139877.py in <cell line: 0>()
# ----> 1 df.groupby("country")["inflation_rate"].mean().sort_values(ascending=False).head(10)
#
# NameError: name 'df' is not defined
